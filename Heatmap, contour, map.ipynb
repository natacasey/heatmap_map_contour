# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('ppg2008.csv')

# %%
df.head()
# Out:
#            Name     G   MIN   PTS   FGM   FGA    FGP  FTM  FTA    FTP  ...  \
# 0    Dwyane Wade   79  38.6  30.2  10.8  22.0  0.491  7.5  9.8  0.765  ...
# 1   LeBron James   81  37.7  28.4   9.7  19.9  0.489  7.3  9.4  0.780  ...
# 2    Kobe Bryant   82  36.2  26.8   9.8  20.9  0.467  5.9  6.9  0.856  ...
# 3  Dirk Nowitzki   81  37.7  25.9   9.6  20.0  0.479  6.0  6.7  0.890  ...
# 4  Danny Granger   67  36.2  25.8   8.5  19.1  0.447  6.0  6.9  0.878  ...
#
#    3PA    3PP  ORB  DRB  TRB  AST  STL  BLK   TO   PF
# 0  3.5  0.317  1.1  3.9  5.0  7.5  2.2  1.3  3.4  2.3
# 1  4.7  0.344  1.3  6.3  7.6  7.2  1.7  1.1  3.0  1.7
# 2  4.1  0.351  1.1  4.1  5.2  4.9  1.5  0.5  2.6  2.3
# 3  2.1  0.359  1.1  7.3  8.4  2.4  0.8  0.8  1.9  2.2
# 4  6.7  0.404  0.7  4.4  5.1  2.7  1.0  1.4  2.5  3.1
#
# [5 rows x 21 columns]

# %%
df=df.drop('PF',1)

# %%
df.head()
# Out:
#            Name     G   MIN   PTS   FGM   FGA    FGP  FTM  FTA    FTP  3PM  \
# 0    Dwyane Wade   79  38.6  30.2  10.8  22.0  0.491  7.5  9.8  0.765  1.1
# 1   LeBron James   81  37.7  28.4   9.7  19.9  0.489  7.3  9.4  0.780  1.6
# 2    Kobe Bryant   82  36.2  26.8   9.8  20.9  0.467  5.9  6.9  0.856  1.4
# 3  Dirk Nowitzki   81  37.7  25.9   9.6  20.0  0.479  6.0  6.7  0.890  0.8
# 4  Danny Granger   67  36.2  25.8   8.5  19.1  0.447  6.0  6.9  0.878  2.7
#
#    3PA    3PP  ORB  DRB  TRB  AST  STL  BLK   TO
# 0  3.5  0.317  1.1  3.9  5.0  7.5  2.2  1.3  3.4
# 1  4.7  0.344  1.3  6.3  7.6  7.2  1.7  1.1  3.0
# 2  4.1  0.351  1.1  4.1  5.2  4.9  1.5  0.5  2.6
# 3  2.1  0.359  1.1  7.3  8.4  2.4  0.8  0.8  1.9
# 4  6.7  0.404  0.7  4.4  5.1  2.7  1.0  1.4  2.5

# %%
list(df.columns)
# Out:
# ['Name  ',
#  'G',
#  'MIN',
#  'PTS',
#  'FGM',
#  'FGA',
#  'FGP',
#  'FTM',
#  'FTA',
#  'FTP',
#  '3PM',
#  '3PA',
#  '3PP',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TO']

# %%
df = df.set_index('Name  ')

# %%
import numpy as np
scaled_df = (df - df.min(axis=0))/(df.max(axis=0) - df.min(axis=0))
fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(scaled_df,  cmap="Blues",
           linewidth=0.3, cbar_kws={"shrink": .8}, cbar=False)
ax.xaxis.tick_bottom()
xticks_labels = ['Games', 'Minutes', 'Points', 'Field goals', 'F.G.Attempts', 'F.G.Percentage',
                'Free Throws', 'F.Th.Attempts', 'F.Th.Percentage', 'Three Pointer', 'Th.P.Attempts', 'Th.P.Percentage', 'Offen. Rebounds','Defen. Rebounds','Total Rebounds','Assists', 'Steals', 'Blocks', 'Turnovers']
plt.xticks(np.arange(19)+.5, labels=xticks_labels, rotation='vertical')
ax.set_title('\nNBA PERFORMANCE\n', fontsize=19,  loc='left', color='dimgray')
plt.ylabel('')
plt.show()

# %%
df = pd.read_csv('Data 4_Migrated Data.csv')

# %%
df.head()
# Out:
#    Alpha   Colour Date  Goals Conceded  Goals Scored  ID1  ID2 Location  \
# 0    NaN  #d02320  NaN             NaN           NaN  1.0  NaN      NaN
# 1    NaN  #d02320  NaN             NaN           NaN  2.0  NaN      NaN
# 2    NaN  #d02320  NaN             NaN           NaN  3.0  NaN      NaN
# 3    NaN  #d02320  NaN             NaN           NaN  4.0  NaN      NaN
# 4    NaN  #d02320  NaN             NaN           NaN  5.0  NaN      NaN
#
#        Location 2     NA  ...  Result  Result 2 Score Team Against  Level  \
# 0  away from home  1-001  ...     NaN       NaN   NaN          NaN  0.005
# 1  away from home  1-001  ...     NaN       NaN   NaN          NaN  0.005
# 2  away from home  1-001  ...     NaN       NaN   NaN          NaN  0.005
# 3  away from home  1-001  ...     NaN       NaN   NaN          NaN  0.005
# 4  away from home  1-001  ...     NaN       NaN   NaN          NaN  0.005
#
#   Linetype  Number of Records  Size          X          Y
# ...

# %%
list(df.columns)
# Out:
# ['Alpha',
#  'Colour',
#  'Date',
#  'Goals Conceded',
#  'Goals Scored',
#  'ID1',
#  'ID2',
#  'Location',
#  'Location 2',
#  'NA',
#  'Na 1',
#  'Piece',
#  'Result',
#  'Result 2',
#  'Score',
#  'Team Against',
#  'Level',
#  'Linetype',
#  'Number of Records',
#  'Size',
#  'X',
#  'Y']

# %%
df.head()
# Out:
#    Alpha   Colour Date  Goals Conceded  Goals Scored  ID1  ID2 Location  \
# 0    NaN  #d02320  NaN             NaN           NaN  1.0  NaN      NaN
# 1    NaN  #d02320  NaN             NaN           NaN  2.0  NaN      NaN
# 2    NaN  #d02320  NaN             NaN           NaN  3.0  NaN      NaN
# 3    NaN  #d02320  NaN             NaN           NaN  4.0  NaN      NaN
# 4    NaN  #d02320  NaN             NaN           NaN  5.0  NaN      NaN
#
#        Location 2     NA  ...  Result  Result 2 Score Team Against  Level  \
# 0  away from home  1-001  ...     NaN       NaN   NaN          NaN  0.005
# 1  away from home  1-001  ...     NaN       NaN   NaN          NaN  0.005
# 2  away from home  1-001  ...     NaN       NaN   NaN          NaN  0.005
# 3  away from home  1-001  ...     NaN       NaN   NaN          NaN  0.005
# 4  away from home  1-001  ...     NaN       NaN   NaN          NaN  0.005
#
#   Linetype  Number of Records  Size          X          Y
# ...

# %%
df = df.dropna(subset=['Team Against', 'Result 2','ID2'])

# %%
NA1=df['Na 1']== 4
df= df[NA1]
df.head()
# Out:
#       Alpha Colour                       Date  Goals Conceded  Goals Scored  \
# 4459    NaN    NaN    Saturday, 8 August 2015             1.0           0.0
# 4464    NaN    NaN   Saturday, 15 August 2015             2.0           2.0
# 4467    NaN    NaN   Saturday, 22 August 2015             1.0           1.0
# 4474    NaN    NaN   Saturday, 29 August 2015             0.0           0.0
# 4477    NaN    NaN  Sunday, 13 September 2015             0.0           1.0
#
#       ID1   ID2 Location      Location 2   NA  ...  Result  Result 2 Score  \
# 4459  NaN  27.0     Away  away from home  NaN  ...    Lost      lost   1-0
# 4464  NaN  28.0     Home         at home  NaN  ...    Draw      drew   2-2
# 4467  NaN  29.0     Away  away from home  NaN  ...    Draw      drew   1-1
# 4474  NaN  30.0     Home         at home  NaN  ...    Draw      drew   0-0
# 4477  NaN  31.0     Away  away from home  NaN  ...     Won       won   1-0
#
# ...

# %%
df.dropna(subset=['Team Against',  'Result 2','ID2'])
# Out:
#       Alpha Colour                         Date  Goals Conceded  Goals Scored  \
# 4459    NaN    NaN      Saturday, 8 August 2015             1.0           0.0
# 4464    NaN    NaN     Saturday, 15 August 2015             2.0           2.0
# 4467    NaN    NaN     Saturday, 22 August 2015             1.0           1.0
# 4474    NaN    NaN     Saturday, 29 August 2015             0.0           0.0
# 4477    NaN    NaN    Sunday, 13 September 2015             0.0           1.0
# 4482    NaN    NaN    Sunday, 20 September 2015             0.0           1.0
# 4486    NaN    NaN  Saturday, 26 September 2015             1.0           4.0
# 4489    NaN    NaN       Sunday, 4 October 2015             2.0           2.0
# 4494    NaN    NaN    Saturday, 17 October 2015             0.0           0.0
# 4498    NaN    NaN      Sunday, 25 October 2015             1.0           5.0
# 4502    NaN    NaN      Monday, 2 November 2015             1.0           3.0
# ...

# %%
result =df['Result 2']== 'lost'
data= df[result]
data.head()
# Out:
#       Alpha Colour                        Date  Goals Conceded  Goals Scored  \
# 4459    NaN    NaN     Saturday, 8 August 2015             1.0           0.0
# 4521    NaN    NaN    Sunday, 13 December 2015             2.0           1.0
# 4542    NaN    NaN  Wednesday, 13 January 2016             1.0           0.0
#
#       ID1   ID2 Location      Location 2   NA  ...  Result  Result 2 Score  \
# 4459  NaN  27.0     Away  away from home  NaN  ...    Lost      lost   1-0
# 4521  NaN  42.0     Home         at home  NaN  ...    Lost      lost   2-1
# 4542  NaN  47.0     Home         at home  NaN  ...    Lost      lost   1-0
#
#            Team Against Level Linetype  Number of Records  Size      X     Y
# 4459  Manchester United   NaN      NaN                  1   NaN  19.79  80.0
# 4521   Newcastle United   NaN      NaN                  1   NaN  18.54  76.0
# 4542     Leicester City   NaN      NaN                  1   NaN  20.57  80.0
#
# [3 rows x 22 columns]

# %%
data = data.rename(columns={'Result 2': 'Result_2','Team Against': 'Team'})

# %%
data.head()
# Out:
#       Alpha Colour                        Date  Goals Conceded  Goals Scored  \
# 4459    NaN    NaN     Saturday, 8 August 2015             1.0           0.0
# 4521    NaN    NaN    Sunday, 13 December 2015             2.0           1.0
# 4542    NaN    NaN  Wednesday, 13 January 2016             1.0           0.0
#
#       ID1   ID2 Location      Location 2   NA  ...  Result  Result_2 Score  \
# 4459  NaN  27.0     Away  away from home  NaN  ...    Lost      lost   1-0
# 4521  NaN  42.0     Home         at home  NaN  ...    Lost      lost   2-1
# 4542  NaN  47.0     Home         at home  NaN  ...    Lost      lost   1-0
#
#                    Team Level Linetype  Number of Records  Size      X     Y
# 4459  Manchester United   NaN      NaN                  1   NaN  19.79  80.0
# 4521   Newcastle United   NaN      NaN                  1   NaN  18.54  76.0
# 4542     Leicester City   NaN      NaN                  1   NaN  20.57  80.0
#
# [3 rows x 22 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(14, 12))
# Basic 2D density plot
sns.set_style("white")
sns.kdeplot(df.X, df.Y)
#sns.plt.show()
 
# Custom it with the same argument as 1D density plot
sns.kdeplot(df.X, df.Y, cmap="Oranges")
sns.scatterplot(data=df, x="X", y="Y", color = 'dimgray', s = 100, alpha=0.4)
 
# Some features are characteristic of 2D: color palette and wether or not color the lowest range
#sns.kdeplot(df.X, df.Y,  shade=True, shade_lowest=True, )
#sns.plt.show()
plt.title('\nPASSES AND PERFORMANCE BY TOTTENHAM HOTSPUR\n', color='dimgray', loc='left', fontsize =18)
# Set x-axis label
plt.xlabel('\npass length (m)\n', fontsize = 14, color='dimgray')
# Set y-axis label
plt.ylabel('pass completion (%)\n', fontsize = 14, color='dimgray')


def label_point(x, y, val, val1, ax):
    a = pd.concat({'x': x, 'y': y, 'val':val, 'val1':val1 }, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']-.3, point['y']-0.5, str(point['val']+' '+'to'+ '\n'+point['val1']+'    '), fontsize=10.5, color = 'black')

label_point(data.X, data.Y, data.Result_2, data.Team, plt.gca())
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.tick_params(axis='x', labelsize=13) 
ax.tick_params(axis='y', labelsize=13) 
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv('costcos-geocoded.csv')

# %%
df2.head()
# Out:
#                      Address        City    State    Zip Code   Latitude  \
# 0   1205 N. Memorial Parkway  Huntsville  Alabama  35801-5930  34.743095
# 1       3650 Galleria Circle      Hoover  Alabama  35244-2346  33.377649
# 2     8251 Eastchase Parkway  Montgomery  Alabama       36117  32.363889
# 3  5225 Commercial Boulevard      Juneau   Alaska  99801-7210  58.359200
# 4       330 West Dimond Blvd   Anchorage   Alaska  99515-1950  61.143266
#
#     Longitude
# 0  -86.600955
# 1  -86.812420
# 2  -86.150884
# 3 -134.483000
# 4 -149.884217

# %%
latitude = df2['Latitude']
longitude = df2['Longitude']

# %%
from mpl_toolkits.basemap import Basemap
fig, ax = plt.subplots(figsize=(20, 20))
map=Basemap(llcrnrlat=24,urcrnrlat=50,llcrnrlon=-130,urcrnrlon=-55,projection='cyl',resolution='c', suppress_ticks = True)
map.drawcoastlines()
map.drawcountries()
map.drawstates(color='dimgray')
plt.scatter(longitude, latitude, c='darkorange', alpha=0.7,s=130, edgecolors='lightgray')
plt.title('\nCOSTCO STORES IN THE CONTIGUOUS USA\n', color='dimgray', loc='left', fontsize =18)
ax.axis("off") 
plt.show()
